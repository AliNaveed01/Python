# %%
import cv2 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
def extract_frames(video_path, output_folder, frame_interval=50):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Open the video file
    cap = cv2.VideoCapture(video_path)
    
    # Check if the video opened successfully
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        return
    
    frame_count = 0
    extracted_count = 0
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # If the frame was read successfully
        if ret:
            # Save frame if it is in the specified interval
            if frame_count % frame_interval == 0:
                frame_filename = os.path.join(output_folder, f"frame_{frame_count:06d}.jpg")
                cv2.imwrite(frame_filename, frame)
                extracted_count += 1
            
            frame_count += 1
        else:
            break
    
    cap.release()
    print(f"Extracted {extracted_count} frames from {video_path}")

# Example usage
video_path = "Driving Downtown - New York City 4K - USA.mp4"
output_folder = "extracted_3"
frame_interval = 50  # Save every 30th frame

extract_frames(video_path, output_folder, frame_interval)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 40
#      37 output_folder = "extracted_3"
#      38 frame_interval = 50  # Save every 30th frame
# ---> 40 extract_frames(video_path, output_folder, frame_interval)
#
# Cell In[4], line 18, in extract_frames(video_path, output_folder, frame_interval)
#      15 extracted_count = 0
#      17 while cap.isOpened():
# ---> 18     ret, frame = cap.read()
#      20     # If the frame was read successfully
#      21     if ret:
#      22         # Save frame if it is in the specified interval
#
# KeyboardInterrupt:

# %%
def extract_frames(video_path, output_folder, frame_interval):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Open the video file
    cap = cv2.VideoCapture(video_path)
    
    # Check if the video opened successfully
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        return
    
    frame_count = 0
    extracted_count = 0
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # If the frame was read successfully
        if ret:
            # Save frame if it is in the specified interval
            if frame_count % frame_interval == 0:
                frame_filename = os.path.join(output_folder, f"frame_{frame_count:06d}.jpg")
                cv2.imwrite(frame_filename, frame)
                extracted_count += 1
            
            frame_count += 1
        else:
            break
    
    cap.release()
    print(f"Extracted {extracted_count} frames from {video_path}")

# Example usage
video_path = "Aerial View Cars Aerial View.mp4"
output_folder = "extracted_2"
frame_interval = 10  # Save every 30th frame

extract_frames(video_path, output_folder, frame_interval)
# Out:
# Extracted 184 frames from Aerial View Cars Aerial View.mp4

# %%
def extract_frames(video_path, output_folder, frame_interval):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Open the video file
    cap = cv2.VideoCapture(video_path)
    
    # Check if the video opened successfully
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        return
    
    frame_count = 0
    extracted_count = 0
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # If the frame was read successfully
        if ret:
            # Save frame if it is in the specified interval
            if frame_count % frame_interval == 0:
                frame_filename = os.path.join(output_folder, f"frame_{frame_count:06d}.jpg")
                cv2.imwrite(frame_filename, frame)
                extracted_count += 1
            
            frame_count += 1
        else:
            break
    
    cap.release()
    print(f"Extracted {extracted_count} frames from {video_path}")

# Example usage
video_path = "gettyimages-824604982-640_adpp.mp4"
output_folder = "extracted_3"
frame_interval = 10  # Save every 30th frame

extract_frames(video_path, output_folder, frame_interval)
# Out:
# Extracted 42 frames from gettyimages-824604982-640_adpp.mp4

# %%
def extract_frames(video_path, output_folder, frame_interval):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Open the video file
    cap = cv2.VideoCapture(video_path)
    
    # Check if the video opened successfully
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        return
    
    frame_count = 0
    extracted_count = 0
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # If the frame was read successfully
        if ret:
            # Save frame if it is in the specified interval
            if frame_count % frame_interval == 0:
                frame_filename = os.path.join(output_folder, f"frame_{frame_count:06d}.jpg")
                cv2.imwrite(frame_filename, frame)
                extracted_count += 1
            
            frame_count += 1
        else:
            break
    
    cap.release()
    print(f"Extracted {extracted_count} frames from {video_path}")

# Example usage
video_path = "gettyimages-1269124601-640_adpp.mp4"
output_folder = "extracted_4"
frame_interval = 10  # Save every 30th frame

extract_frames(video_path, output_folder, frame_interval)
# Out:
# Extracted 21 frames from gettyimages-1269124601-640_adpp.mp4

# %%
def extract_frames(video_path, output_folder, frame_interval):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Open the video file
    cap = cv2.VideoCapture(video_path)
    
    # Check if the video opened successfully
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        return
    
    frame_count = 0
    extracted_count = 0
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # If the frame was read successfully
        if ret:
            # Save frame if it is in the specified interval
            if frame_count % frame_interval == 0:
                frame_filename = os.path.join(output_folder, f"frame_{frame_count:06d}.jpg")
                cv2.imwrite(frame_filename, frame)
                extracted_count += 1
            
            frame_count += 1
        else:
            break
    
    cap.release()
    print(f"Extracted {extracted_count} frames from {video_path}")

# Example usage
video_path = "gettyimages-1269128121-640_adpp.mp4"
output_folder = "extracted_5"
frame_interval = 10  # Save every 30th frame

extract_frames(video_path, output_folder, frame_interval)
# Out:
# Extracted 24 frames from gettyimages-1269128121-640_adpp.mp4

# %%
def extract_frames(video_path, output_folder, frame_interval):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Open the video file
    cap = cv2.VideoCapture(video_path)
    
    # Check if the video opened successfully
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        return
    
    frame_count = 0
    extracted_count = 0
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # If the frame was read successfully
        if ret:
            # Save frame if it is in the specified interval
            if frame_count % frame_interval == 0:
                frame_filename = os.path.join(output_folder, f"frame_{frame_count:06d}.jpg")
                cv2.imwrite(frame_filename, frame)
                extracted_count += 1
            
            frame_count += 1
        else:
            break
    
    cap.release()
    print(f"Extracted {extracted_count} frames from {video_path}")

# Example usage
video_path = "gettyimages-1270373175-640_adpp.mp4"
output_folder = "extracted_6"
frame_interval = 10  # Save every 30th frame

extract_frames(video_path, output_folder, frame_interval)
# Out:
# Extracted 28 frames from gettyimages-1270373175-640_adpp.mp4

# %%
def extract_frames(video_path, output_folder, frame_interval):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Open the video file
    cap = cv2.VideoCapture(video_path)
    
    # Check if the video opened successfully
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        return
    
    frame_count = 0
    extracted_count = 0
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # If the frame was read successfully
        if ret:
            # Save frame if it is in the specified interval
            if frame_count % frame_interval == 0:
                frame_filename = os.path.join(output_folder, f"frame_{frame_count:06d}.jpg")
                cv2.imwrite(frame_filename, frame)
                extracted_count += 1
            
            frame_count += 1
        else:
            break
    
    cap.release()
    print(f"Extracted {extracted_count} frames from {video_path}")

# Example usage
video_path = "gettyimages-695104461-640_adpp.mp4"
output_folder = "extracted_7"
frame_interval = 10  # Save every 30th frame

extract_frames(video_path, output_folder, frame_interval)
# Out:
# Extracted 85 frames from gettyimages-695104461-640_adpp.mp4

# %%
def extract_frames(video_path, output_folder, frame_interval):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Open the video file
    cap = cv2.VideoCapture(video_path)
    
    # Check if the video opened successfully
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        return
    
    frame_count = 0
    extracted_count = 0
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # If the frame was read successfully
        if ret:
            # Save frame if it is in the specified interval
            if frame_count % frame_interval == 0:
                frame_filename = os.path.join(output_folder, f"frame_{frame_count:06d}.jpg")
                cv2.imwrite(frame_filename, frame)
                extracted_count += 1
            
            frame_count += 1
        else:
            break
    
    cap.release()
    print(f"Extracted {extracted_count} frames from {video_path}")

# Example usage
video_path = "gettyimages-1338655046-640_adpp.mp4"
output_folder = "extracted_8"
frame_interval = 10  # Save every 30th frame

extract_frames(video_path, output_folder, frame_interval)
# Out:
# Extracted 17 frames from gettyimages-1338655046-640_adpp.mp4

# %%
def extract_frames(video_path, output_folder, frame_interval):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Open the video file
    cap = cv2.VideoCapture(video_path)
    
    # Check if the video opened successfully
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        return
    
    frame_count = 0
    extracted_count = 0
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # If the frame was read successfully
        if ret:
            # Save frame if it is in the specified interval
            if frame_count % frame_interval == 0:
                frame_filename = os.path.join(output_folder, f"frame_{frame_count:06d}.jpg")
                cv2.imwrite(frame_filename, frame)
                extracted_count += 1
            
            frame_count += 1
        else:
            break
    
    cap.release()
    print(f"Extracted {extracted_count} frames from {video_path}")

# Example usage
video_path = "gettyimages-1344566496-640_adpp.mp4"
output_folder = "extracted_9"
frame_interval = 10  # Save every 30th frame

extract_frames(video_path, output_folder, frame_interval)
# Out:
# Extracted 73 frames from gettyimages-1344566496-640_adpp.mp4

# %%
def extract_frames(video_path, output_folder, frame_interval):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Open the video file
    cap = cv2.VideoCapture(video_path)
    
    # Check if the video opened successfully
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        return
    
    frame_count = 0
    extracted_count = 0
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # If the frame was read successfully
        if ret:
            # Save frame if it is in the specified interval
            if frame_count % frame_interval == 0:
                frame_filename = os.path.join(output_folder, f"frame_{frame_count:06d}.jpg")
                cv2.imwrite(frame_filename, frame)
                extracted_count += 1
            
            frame_count += 1
        else:
            break
    
    cap.release()
    print(f"Extracted {extracted_count} frames from {video_path}")

# Example usage
video_path = "gettyimages-1372074913-640_adpp.mp4"
output_folder = "extracted_10"
frame_interval = 10  # Save every 30th frame

extract_frames(video_path, output_folder, frame_interval)
# Out:
# Extracted 74 frames from gettyimages-1372074913-640_adpp.mp4

# %%
def extract_frames(video_path, output_folder, frame_interval):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Open the video file
    cap = cv2.VideoCapture(video_path)
    
    # Check if the video opened successfully
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        return
    
    frame_count = 0
    extracted_count = 0
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # If the frame was read successfully
        if ret:
            # Save frame if it is in the specified interval
            if frame_count % frame_interval == 0:
                frame_filename = os.path.join(output_folder, f"frame_{frame_count:06d}.jpg")
                cv2.imwrite(frame_filename, frame)
                extracted_count += 1
            
            frame_count += 1
        else:
            break
    
    cap.release()
    print(f"Extracted {extracted_count} frames from {video_path}")

# Example usage
video_path = "gettyimages-1374701880-640_adpp.mp4"
output_folder = "extracted_11"
frame_interval = 10  # Save every 30th frame

extract_frames(video_path, output_folder, frame_interval)
# Out:
# Extracted 37 frames from gettyimages-1374701880-640_adpp.mp4

# %%
def extract_frames(video_path, output_folder, frame_interval):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Open the video file
    cap = cv2.VideoCapture(video_path)
    
    # Check if the video opened successfully
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        return
    
    frame_count = 0
    extracted_count = 0
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # If the frame was read successfully
        if ret:
            # Save frame if it is in the specified interval
            if frame_count % frame_interval == 0:
                frame_filename = os.path.join(output_folder, f"frame_{frame_count:06d}.jpg")
                cv2.imwrite(frame_filename, frame)
                extracted_count += 1
            
            frame_count += 1
        else:
            break
    
    cap.release()
    print(f"Extracted {extracted_count} frames from {video_path}")

# Example usage
video_path = "gettyimages-1374705657-640_adpp.mp4"
output_folder = "extracted_12"
frame_interval = 10  # Save every 30th frame

extract_frames(video_path, output_folder, frame_interval)
# Out:
# Extracted 47 frames from gettyimages-1374705657-640_adpp.mp4

# %%
def extract_frames(video_path, output_folder, frame_interval):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Open the video file
    cap = cv2.VideoCapture(video_path)
    
    # Check if the video opened successfully
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        return
    
    frame_count = 0
    extracted_count = 0
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # If the frame was read successfully
        if ret:
            # Save frame if it is in the specified interval
            if frame_count % frame_interval == 0:
                frame_filename = os.path.join(output_folder, f"frame_{frame_count:06d}.jpg")
                cv2.imwrite(frame_filename, frame)
                extracted_count += 1
            
            frame_count += 1
        else:
            break
    
    cap.release()
    print(f"Extracted {extracted_count} frames from {video_path}")

# Example usage
video_path = "gettyimages-1388915074-640_adpp.mp4"
output_folder = "extracted_13"
frame_interval = 10  # Save every 30th frame

extract_frames(video_path, output_folder, frame_interval)
# Out:
# Extracted 80 frames from gettyimages-1388915074-640_adpp.mp4

# %%
def extract_frames(video_path, output_folder, frame_interval):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Open the video file
    cap = cv2.VideoCapture(video_path)
    
    # Check if the video opened successfully
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        return
    
    frame_count = 0
    extracted_count = 0
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # If the frame was read successfully
        if ret:
            # Save frame if it is in the specified interval
            if frame_count % frame_interval == 0:
                frame_filename = os.path.join(output_folder, f"frame_{frame_count:06d}.jpg")
                cv2.imwrite(frame_filename, frame)
                extracted_count += 1
            
            frame_count += 1
        else:
            break
    
    cap.release()
    print(f"Extracted {extracted_count} frames from {video_path}")

# Example usage
video_path = "gettyimages-1390080497-640_adpp (1).mp4"
output_folder = "extracted_14"
frame_interval = 10  # Save every 30th frame

extract_frames(video_path, output_folder, frame_interval)
# Out:
# Extracted 56 frames from gettyimages-1390080497-640_adpp (1).mp4

# %%
def extract_frames(video_path, output_folder, frame_interval):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Open the video file
    cap = cv2.VideoCapture(video_path)
    
    # Check if the video opened successfully
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        return
    
    frame_count = 0
    extracted_count = 0
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # If the frame was read successfully
        if ret:
            # Save frame if it is in the specified interval
            if frame_count % frame_interval == 0:
                frame_filename = os.path.join(output_folder, f"frame_{frame_count:06d}.jpg")
                cv2.imwrite(frame_filename, frame)
                extracted_count += 1
            
            frame_count += 1
        else:
            break
    
    cap.release()
    print(f"Extracted {extracted_count} frames from {video_path}")

# Example usage
video_path = "gettyimages-1390080497-640_adpp.mp4"
output_folder = "extracted_15"
frame_interval = 10  # Save every 30th frame

extract_frames(video_path, output_folder, frame_interval)
# Out:
# Extracted 56 frames from gettyimages-1390080497-640_adpp.mp4

# %%
def extract_frames(video_path, output_folder, frame_interval):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Open the video file
    cap = cv2.VideoCapture(video_path)
    
    # Check if the video opened successfully
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        return
    
    frame_count = 0
    extracted_count = 0
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # If the frame was read successfully
        if ret:
            # Save frame if it is in the specified interval
            if frame_count % frame_interval == 0:
                frame_filename = os.path.join(output_folder, f"frame_{frame_count:06d}.jpg")
                cv2.imwrite(frame_filename, frame)
                extracted_count += 1
            
            frame_count += 1
        else:
            break
    
    cap.release()
    print(f"Extracted {extracted_count} frames from {video_path}")

# Example usage
video_path = "gettyimages-1395891953-640_adpp.mp4"
output_folder = "extracted_16"
frame_interval = 10  # Save every 30th frame

extract_frames(video_path, output_folder, frame_interval)
# Out:
# Extracted 88 frames from gettyimages-1395891953-640_adpp.mp4

# %%
def extract_frames(video_path, output_folder, frame_interval):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Open the video file
    cap = cv2.VideoCapture(video_path)
    
    # Check if the video opened successfully
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        return
    
    frame_count = 0
    extracted_count = 0
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # If the frame was read successfully
        if ret:
            # Save frame if it is in the specified interval
            if frame_count % frame_interval == 0:
                frame_filename = os.path.join(output_folder, f"frame_{frame_count:06d}.jpg")
                cv2.imwrite(frame_filename, frame)
                extracted_count += 1
            
            frame_count += 1
        else:
            break
    
    cap.release()
    print(f"Extracted {extracted_count} frames from {video_path}")

# Example usage
video_path = "gettyimages-1396344683-640_adpp.mp4"
output_folder = "extracted_17"
frame_interval = 10  # Save every 30th frame

extract_frames(video_path, output_folder, frame_interval)
# Out:
# Extracted 44 frames from gettyimages-1396344683-640_adpp.mp4

# %%
def extract_frames(video_path, output_folder, frame_interval):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Open the video file
    cap = cv2.VideoCapture(video_path)
    
    # Check if the video opened successfully
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        return
    
    frame_count = 0
    extracted_count = 0
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # If the frame was read successfully
        if ret:
            # Save frame if it is in the specified interval
            if frame_count % frame_interval == 0:
                frame_filename = os.path.join(output_folder, f"frame_{frame_count:06d}.jpg")
                cv2.imwrite(frame_filename, frame)
                extracted_count += 1
            
            frame_count += 1
        else:
            break
    
    cap.release()
    print(f"Extracted {extracted_count} frames from {video_path}")

# Example usage
video_path = "gettyimages-1396344684-640_adpp.mp4"
output_folder = "extracted_18"
frame_interval = 10  # Save every 30th frame

extract_frames(video_path, output_folder, frame_interval)
# Out:
# Extracted 48 frames from gettyimages-1396344684-640_adpp.mp4

# %%
def extract_frames(video_path, output_folder, frame_interval):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Open the video file
    cap = cv2.VideoCapture(video_path)
    
    # Check if the video opened successfully
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        return
    
    frame_count = 0
    extracted_count = 0
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # If the frame was read successfully
        if ret:
            # Save frame if it is in the specified interval
            if frame_count % frame_interval == 0:
                frame_filename = os.path.join(output_folder, f"frame_{frame_count:06d}.jpg")
                cv2.imwrite(frame_filename, frame)
                extracted_count += 1
            
            frame_count += 1
        else:
            break
    
    cap.release()
    print(f"Extracted {extracted_count} frames from {video_path}")

# Example usage
video_path = "gettyimages-1399874101-640_adpp.mp4"
output_folder = "extracted_19"
frame_interval = 10  # Save every 30th frame

extract_frames(video_path, output_folder, frame_interval)
# Out:
# Extracted 182 frames from gettyimages-1399874101-640_adpp.mp4

# %%
def extract_frames(video_path, output_folder, frame_interval):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Open the video file
    cap = cv2.VideoCapture(video_path)
    
    # Check if the video opened successfully
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        return
    
    frame_count = 0
    extracted_count = 0
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # If the frame was read successfully
        if ret:
            # Save frame if it is in the specified interval
            if frame_count % frame_interval == 0:
                frame_filename = os.path.join(output_folder, f"frame_{frame_count:06d}.jpg")
                cv2.imwrite(frame_filename, frame)
                extracted_count += 1
            
            frame_count += 1
        else:
            break
    
    cap.release()
    print(f"Extracted {extracted_count} frames from {video_path}")

# Example usage
video_path = "pexels_videos_2103099 (1080p).mp4"
output_folder = "CarVidFrames"
frame_interval = 10  # Save every 30th frame

extract_frames(video_path, output_folder, frame_interval)
# Out:
# Extracted 180 frames from pexels_videos_2103099 (1080p).mp4

# %%
# now after that we have to rename the images foldervise
import os
i=3
path = 'extracted_'+str(i)
files = os.listdir(path)
for j, file in enumerate(files):  # the newer name will be path name + image + number + .jpg
    os.rename(os.path.join(path, file), os.path.join(path, f'extracted_v{i}image'+str(j)+'.jpg'))
# for i in range(1,2):
    # path = 'extracted_'+str(i)
    # files = os.listdir(path)
    # for j, file in enumerate(files):
    #     # the newer name will be path name + image + number + .jpg
    #     os.rename(os.path.join(path, file), os.path.join(path, f'extracted_v{i}image'+str(j)+'.jpg'))
